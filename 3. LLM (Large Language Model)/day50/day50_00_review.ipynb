# %% [markdown]
# # [1교시] ~ [2교시]

# %%
# 01.ipynb

# %% [markdown]
# # [3교시] ~ [4교시]

# %%
# 02.ipynb

# %% [markdown]
# 파인튜닝, 큐잉, 라마로 튜닝하기 나쁘지 않다

# %% [markdown]
# # [5교시]

# %% [markdown]
# 01.ipynb, 02.ipynb
#
# ### 질의응답 모델 페르소나 제어 실습
# 동일한 지문과 동일한 질문일지라도 시스템 프롬프트에 규정된 페르소나(친절한 유치원 선생님 vs 차갑고 기계적인 인공지능 분석 기계)에 따라 출력 톤앤매너가 완벽하게 다르게 반응하는지 검증합니다.

# %% [markdown]
# # [6교시]

# %% [markdown]
# 03.ipynb

# %% [markdown]
# # [7교시]

# %% [markdown]
# - 1 ~ 4교시 수업한거 runpod에서 localhost8000 해서 health로 확인하고 등
# - q 로라, 로라튜닝은 다음주 화요일에 진도 나갈 예정

# %% [markdown]
# # [8교시]

# %% [markdown]
# 금일 학습 내용 복습
