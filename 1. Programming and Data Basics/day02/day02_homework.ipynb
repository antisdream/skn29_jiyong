# %% [markdown]
# 1. 3명의 사원정보를 리스트에 저장해서 변수로 관리
# {
#   'name' : '홍길동',
#   'pay' : 100000,
#   'status' : '관리자'
# }

# %%
employees = [
    {"name" : "홍길동", "pay" : 100000, "status" : "관리자" },
    {"name" : "고길동", "pay" : 200000, "status" : "부서장" },
    {"name" : "저길동", "pay" : 50000, "status" : "평사원"},
]

# %% [markdown]
# 2. pay가 가장 큰 사원 이름을 출력

# %%
max_pay = 0
highest_paid_employee_name = ""

for employee in employees:
  if employee["pay"] > max_pay:
     max_pay = employee["pay"]
     highest_paid_employee_name = employee["name"]

print(f"pay가 가장 큰 사원은 {highest_paid_employee_name}입니다")
# Out:
# pay가 가장 큰 사원은 고길동입니다

# %% [markdown]
# 3. 임의 집합 두개를 만들어서 교집합, 합집합, 차집합 각 집합중에 가장큰값과 작은값을 찾아서 출력
# a = [random.radint(1,15) for i in range(10)]
# b = [random.radint(1,15) for i in range(10)]

# %%
import random

a = [random.randint(1, 15) for i in range(10)]
b = [random.randint(1, 15) for i in range(10)]

print("a:", a)
print("b:", b)
# Out:
# a: [8, 14, 9, 2, 7, 3, 12, 11, 2, 9]
# b: [4, 8, 8, 5, 14, 10, 5, 14, 11, 8]

# %%
union_set = set(a) | set(b) 

intersection_set = set(a) & set(b)

difference_set = set(a) - set(b)

print(
    [union_set, 
    intersection_set,
    difference_set]
)
# Out:
# [{2, 3, 4, 5, 7, 8, 9, 10, 11, 12, 14}, {8, 11, 14}, {2, 3, 7, 9, 12}]

# %%
print("합집합 : 최대값:", max(union_set), ", 최소값:", min(union_set))
print("교집합 : 최대값:", max(intersection_set), ", 최소값:", min(intersection_set))
print("차집합 : 최대값:", max(difference_set), ", 최소값:", min(difference_set))
# Out:
# 합집합 : 최대값: 14 , 최소값: 2
# 교집합 : 최대값: 14 , 최소값: 8
# 차집합 : 최대값: 12 , 최소값: 2
