# %%
range(5)
range(0, 5)

list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
clean_data = []

for i in [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999]:
    if i != -999:
        clean_data.append(i)
clean_data
# Out:
# [10.2, 10.5, 15.5, 12.6, 20.5, 24.5]

# %%
# 리스트 컴프리핸션... 내포

[ i for i in [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999] ]
# Out:
# [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999]

# %%
# 리스트 컴프리핸션... 내포

[ 'code_' + str(i) for i in [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999] ]
# Out:
# ['code_10.2',
#  'code_10.5',
#  'code_15.5',
#  'code_12.6',
#  'code_-999',
#  'code_20.5',
#  'code_-999',
#  'code_24.5',
#  'code_-999']

# %%
clean_data = []
for i in [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999]:
    if i != -999:
        clean_data.append(i)

# %%
[ i for i in [10.2, 10.5, 15.5, 12.6, -999, 20.5, -999, 24.5, -999] if i != -999]
# Out:
# [10.2, 10.5, 15.5, 12.6, 20.5, 24.5]

# %%
str_data = ['abc', 'test', 'update']
[i.upper() for i in str_data]
# Out:
# ['ABC', 'TEST', 'UPDATE']
