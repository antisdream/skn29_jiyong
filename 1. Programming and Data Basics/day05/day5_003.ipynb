# %%
# 함수의 매개변수가 리스트를 전달받아야 함

def calculate_average(scores):
    return sum(scores) / len(scores)

datas = [1,'a',-1]

try:
    print(calculate_average(datas))
except Exception as e:
    print(f"error : {e}")
# Out:
# error : unsupported operand type(s) for +: 'int' and 'str'

# %%
def calculate_average(scores):
    if type(scores) != list:
        raise TypeError("매개변수는 반드시 리스트 형태가 되어야 합니다.")
    if len(scores) == 0:
        raise ValueError("리스트는 비어있으면 안됩니다.")

    return sum(scores) / len(scores)


datas = []

try:
    print(calculate_average(datas))
except Exception as e:
    print(f"error : {e}")
# Out:
# error : 리스트는 비어있으면 안됩니다.

# %%
def calculate_average(scores):
    if type(scores) != list:
        raise TypeError("매개변수는 반드시 리스트 형태가 되어야 합니다.")
    if len(scores) == 0:
        raise ValueError("리스트는 비어있으면 안됩니다.")

    return sum(scores) / len(scores)


datas = [100, 'a']

try:
    print(calculate_average(datas))
except (TypeError, ValueError) as e:
    print(f"데이터 처리 오류 : {e}")
except Exception as e:
    print(f"error : {e}")
# Out:
# 데이터 처리 오류 : unsupported operand type(s) for +: 'int' and 'str'
