# %%
# 직원정보
person = {
    "id": "sk-001"
    "이름": "김철수",
    "나이": 35,
    "직급": "과장",
    "월급": 5000,
    "스킬": ["Python", "JavaScript", "SQL"],
    "주소": {
        "시": "서울",
        "구": "강남구"
    }
}
# 입사 - 직원 dict 생성
# 조회
# 변경
# 삭제
# 직원 정보는 파일에 저장

# 요구사항
# 1. 생성, 조회, 변경, 삭제, 종료 메뉴를 제공하고 사용자가 해당 메뉴를 선택하면 적절한 로직을 수행한다.
# 2. 프로그램 시작시 파일에서 직원정보를 load한다
# 3. 프로그램 종료 전에 수정된 직원정보를 파일에 저장한다.

# %%
# 직원정보는 어떻게 load 할 것인지? --> json 구조 (딕셔너리)
# 생성 : input을 이용해서 사용자로부터 데이터를 직접 입력 7개
# 조회 : 사용자로부터 key값을 입력받아서 출력, 이름으로 조회하되, id정보는 반드시 보여줌.
# 변경 : id값으로 찾아서 변경한다
# 삭제 : 조회를 해서 나온 직원중에 삭제하고자 하는 직원의 id로 delete한다.
# 종료 : 프로그램에서 사용한 모든 리소스를 해제하고 종료 - 파일 업데이트(덮어쓰기)
